# %% [markdown]
# # Problem Statment
#
# "This dataset contain data for more than 9.5k cars sale in Ukraine.Most of them are used cars so it opens the possibility to analyze features to car operation.This is subset of all car data in Ukraine.Using this er will analayze the

# %% [markdown]
# # Introduction
#
# This Exploratory Data Analysis is to practice Python skills learned till now on a structured data set including loading, inspecting, wrangling, exploring, and drawing conclusions from data. The notebook has observations with each step in order to explain thoroughly how to approach the data set. Based on the observation some questions also are answered in the notebook for the reference though not all of them are explored in the analysis.

# %% [markdown]
# # TASKS TO DO
#
# 4.1 Which type of cars are sold maximum?
# 4.2 What is the co-relation between price and mileage?
# 4.3 How many cars are registered?
# 4.4 Price distribution between registered and non-registered cars.
# 4.5 What is the car price distribution based on Engine Value?
# 4.6 Which Engine Type of cars users preferred maximum?
# 4.7 Establish corelation between all features using heatmap?
# 4.8 Distribution of Price?

# %% [markdown]
# # Domain Knowledge
#
# 1. **Price**: The selling price of the car, which depends on various factors like brand, model, mileage, engine type, and year of manufacturing
#
# 2. **Body Type**: The structure of the car (e.g., sedan, hatchback, SUV, coupe, convertible, etc.), which affects market demand.
#
# 3. **Mileage**: In the context of cars in Ukraine, "mileage" refers to the total distance a vehicle has traveled since it was new, typically measured in kilometers (km).
# **and unit for this column is thousand kilometers  (e.g. 68 = 68000KM)**
#
# “Mileage” refers to the average distance or number of kilometers your car can go on a given quantity of fuel.
#
# 4. **Engine Volume (engV)**: The engine displacement in liters (L). Higher engine volume usually means higher power but lower fuel efficiency.
#
# 5. **Engine Type (engType)**: Fuel type of the engine:
# Petrol (Gasoline) – Common, high availability, and moderate cost.
# Diesel – Better mileage but higher maintenance and environmental concerns.
# Hybrid – A mix of fuel and electric power, improving fuel efficiency.
# Electric (EV) – Zero emissions and low running cost but higher initial price.
# LPG (Liquefied Petroleum Gas) – Alternative fuel that is cheaper but less common.
#
# 6. **Registration**: Whether the car has a valid registration.
# Registered cars have legal clearance and are easier to sell.
# Unregistered cars may require additional paperwork and legal checks.
#
# 7. **Year**:The year the car was manufactured. Older cars tend to be cheaper due to depreciation.
#
# 8. **Model**: The specific version of the car from the manufacturer.
# * Some models hold value better due to reliability and brand reputation.
#
# 9. **Drive Type** =
# * Full (All-Wheel Drive) = Power is delivered to all four wheels automatically, adjusting based on road conditions.
# * Rear (Rear-Wheel Drive) = Power is delivered to the rear wheels, while the front wheels handle steering.
# * Front (Front-Wheel Drive) = Power is delivered to the front wheels,

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\Admiin\Downloads\Car_Sales.xlsx")

# %%
df
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.3+ KB

# %%
df.head()
# Out:
#              car    price       body  mileage  engV engType registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas          yes
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4  Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
df.tail()
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# 9571  2011     Tucson  front
# 9572  1986  Passat B2  front
# 9573  2008     ML 350   full
# 9574  2008     ES 350  front
# 9575  2007         Q7   full

# %%
df.size
# Out:
# 95760

# %%
df.shape
# Out:
# (9576, 10)

# %%
df.columns
# Out:
# Index(['car', 'price', 'body', 'mileage', 'engV', 'engType', 'registration',
#        'year', 'model', 'drive'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9576 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.3+ KB

# %%
df.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %%
df.describe(include = "O") #for object data type.
# Out:
#                car   body engType registration    model  drive
# count         9576   9576    9576         9576     9576   9065
# unique          87      6       4            2      863      3
# top     Volkswagen  sedan  Petrol          yes  E-Class  front
# freq           936   3646    4379         9015      199   5188

# %%
df["car"].unique()
# Out:
# array(['Ford', 'Mercedes-Benz', 'Nissan', 'Honda', 'Renault', 'BMW',
#        'Land Rover', 'Volkswagen', 'Audi', 'Chrysler', 'Jaguar',
#        'Mitsubishi', 'Kia', 'Porsche', 'Toyota', 'Hyundai', 'Opel',
#        'Chevrolet', 'Skoda', 'Daewoo', 'Mazda', 'Lexus', 'Infiniti',
#        'Tesla', 'Subaru', 'VAZ', 'Alfa Romeo', 'Smart', 'Peugeot',
#        'Suzuki', 'Chery', 'Bentley', 'Volvo', 'SsangYong', 'Fiat', 'ZAZ',
#        'Citroen', 'Dodge', 'Jeep', 'Great Wall', 'Seat', 'MINI', 'Dacia',
#        'Hummer', 'Geely', 'Maserati', 'BYD', 'Cadillac', 'Acura',
#        'Aston Martin', 'Rover', 'GAZ', 'GMC', 'Lincoln', '�UAZ',
#        'Moskvich-AZLK', 'FAW', 'UAZ', 'Rolls-Royce', 'TATA', 'ZX',
#        'Lifan', 'Mercury', 'Groz', 'Moskvich-Izh', 'Saab', 'Lancia',
#        'Aro', 'Ferrari', 'Isuzu', 'Bogdan', 'Dadi', 'Other-Retro', 'MG',
#        'Samand', 'JAC', 'Samsung', 'Lamborghini', 'Daihatsu', 'Hafei',
#        'SMA', 'Fisker', 'Changan', 'Barkas', 'Huanghai', 'Wartburg',
# ...

# %%
for i in df.columns:
    if df[i].dtype == "O":
        print("Column name:",i)
        print(df[i].unique())
        print("-"*70)
# Out:
# Column name: car
# ['Ford' 'Mercedes-Benz' 'Nissan' 'Honda' 'Renault' 'BMW' 'Land Rover'
#  'Volkswagen' 'Audi' 'Chrysler' 'Jaguar' 'Mitsubishi' 'Kia' 'Porsche'
#  'Toyota' 'Hyundai' 'Opel' 'Chevrolet' 'Skoda' 'Daewoo' 'Mazda' 'Lexus'
#  'Infiniti' 'Tesla' 'Subaru' 'VAZ' 'Alfa Romeo' 'Smart' 'Peugeot' 'Suzuki'
#  'Chery' 'Bentley' 'Volvo' 'SsangYong' 'Fiat' 'ZAZ' 'Citroen' 'Dodge'
#  'Jeep' 'Great Wall' 'Seat' 'MINI' 'Dacia' 'Hummer' 'Geely' 'Maserati'
#  'BYD' 'Cadillac' 'Acura' 'Aston Martin' 'Rover' 'GAZ' 'GMC' 'Lincoln'
#  '�UAZ' 'Moskvich-AZLK' 'FAW' 'UAZ' 'Rolls-Royce' 'TATA' 'ZX' 'Lifan'
#  'Mercury' 'Groz' 'Moskvich-Izh' 'Saab' 'Lancia' 'Aro' 'Ferrari' 'Isuzu'
#  'Bogdan' 'Dadi' 'Other-Retro' 'MG' 'Samand' 'JAC' 'Samsung' 'Lamborghini'
#  'Daihatsu' 'Hafei' 'SMA' 'Fisker' 'Changan' 'Barkas' 'Huanghai'
#  'Wartburg' 'Buick']
# ----------------------------------------------------------------------
# Column name: body
# ['crossover' 'sedan' 'other' 'van' 'vagon' 'hatch']
# ...

# %%
df.duplicated().sum() #how many duplicate alue are there.
# Out:
# 113

# %%
df[df.duplicated()]
# Out:
#                 car     price       body  mileage  engV engType registration  \
# 18           Nissan   16600.0  crossover       83   2.0  Petrol          yes
# 42    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# 70    Mercedes-Benz       0.0  crossover        0   3.0  Diesel          yes
# 86           Toyota  103999.0  crossover        0   4.5  Diesel          yes
# 98    Mercedes-Benz   20400.0      sedan      190   1.8     Gas          yes
# ...             ...       ...        ...      ...   ...     ...          ...
# 9156     Volkswagen   15700.0      sedan      110   1.8  Petrol          yes
# 9163  Mercedes-Benz   20500.0      sedan      222   5.5  Petrol          yes
# 9164            VAZ    3900.0      hatch      121   1.4  Petrol          yes
# 9169        Hyundai   12900.0  crossover       49   2.7  Petrol          yes
# 9477            BMW   77777.0      sedan        8   4.4  Petrol          yes
#
#       year             model  drive
# ...

# %%
df.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           511
# dtype: int64

# %%
round(((df.isnull().sum()) / len(df)) * 100 , 2)
# Out:
# car             0.00
# price           0.00
# body            0.00
# mileage         0.00
# engV            4.53
# engType         0.00
# registration    0.00
# year            0.00
# model           0.00
# drive           5.34
# dtype: float64

# %%
# replace null value from engV (mean,median,mode), for drive(mode)

# %%
df[df["engV"].isnull()]
# Out:
#                 car      price   body  mileage  engV engType registration  \
# 4     Mercedes-Benz  33000.000  vagon       91   NaN   Other          yes
# 13              BMW   4700.000  sedan      200   NaN  Petrol          yes
# 30           Nissan  13980.000  hatch       31   NaN   Other          yes
# 31           Nissan  17300.000  hatch       24   NaN   Other          yes
# 37             Audi   2850.000  sedan      260   NaN   Other           no
# ...             ...        ...    ...      ...   ...     ...          ...
# 9470       Chrysler      0.000  vagon      198   NaN  Petrol          yes
# 9480        Renault   8100.000    van      135   NaN  Diesel          yes
# 9515        Renault   5000.000  vagon      150   NaN   Other          yes
# 9546            VAZ    907.725  sedan        1   NaN   Other          yes
# 9566            UAZ    850.000    van      255   NaN   Other          yes
#
#       year         model  drive
# 4     2013       E-Class    NaN
# ...

# %%
df[df["engV"].isnull()].index
# Out:
# Index([   4,   13,   30,   31,   37,   41,   56,  107,  109,  137,
#        ...
#        9383, 9396, 9419, 9425, 9440, 9470, 9480, 9515, 9546, 9566],
#       dtype='int64', length=434)

# %%
np.where(df.engV.isnull()) #you'll get the index value where is null value.
# Out:
# (array([   4,   13,   30,   31,   37,   41,   56,  107,  109,  137,  150,
#          212,  231,  239,  240,  247,  259,  273,  275,  276,  310,  316,
#          319,  334,  337,  338,  341,  363,  371,  386,  390,  427,  460,
#          468,  524,  550,  553,  560,  563,  565,  579,  627,  650,  663,
#          666,  667,  676,  693,  708,  732,  733,  735,  765,  796,  805,
#          837,  860,  894,  897,  905,  909,  911,  943,  946,  976,  994,
#         1002, 1005, 1027, 1040, 1050, 1054, 1063, 1074, 1088, 1117, 1151,
#         1153, 1159, 1162, 1164, 1179, 1211, 1242, 1289, 1316, 1345, 1350,
#         1404, 1420, 1422, 1431, 1437, 1459, 1466, 1486, 1508, 1537, 1556,
#         1572, 1587, 1624, 1682, 1683, 1719, 1723, 1739, 1740, 1793, 1822,
#         1832, 1902, 1941, 1954, 1960, 1985, 1995, 2011, 2057, 2090, 2114,
#         2115, 2134, 2155, 2163, 2189, 2237, 2267, 2270, 2337, 2347, 2408,
#         2419, 2432, 2468, 2484, 2486, 2487, 2489, 2514, 2516, 2554, 2617,
# ...

# %% [markdown]
# # data cleaning

# %%
df.describe()
# Out:
#                price      mileage         engV         year
# count    9576.000000  9576.000000  9142.000000  9576.000000
# mean    15633.317316   138.862364     2.646344  2006.605994
# std     24106.523436    98.629754     5.927699     7.067924
# min         0.000000     0.000000     0.100000  1953.000000
# 25%      4999.000000    70.000000     1.600000  2004.000000
# 50%      9200.000000   128.000000     2.000000  2008.000000
# 75%     16700.000000   194.000000     2.500000  2012.000000
# max    547800.000000   999.000000    99.990000  2016.000000

# %% [markdown]
# # drop the duplicate values

# %%
df.drop_duplicates(keep = "first",inplace = True)
df
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
len(df) - df.duplicated().sum()
# Out:
# 9463

# %%
df["car"] = df["car"].apply(lambda x : x.strip("�"))

# %%
df["car"]
# Out:
# 0                Ford
# 1       Mercedes-Benz
# 2       Mercedes-Benz
# 3       Mercedes-Benz
# 4       Mercedes-Benz
#             ...
# 9571          Hyundai
# 9572       Volkswagen
# 9573    Mercedes-Benz
# 9574            Lexus
# 9575             Audi
# Name: car, Length: 9463, dtype: object

# %%
df.car.unique()
# Out:
# array(['Ford', 'Mercedes-Benz', 'Nissan', 'Honda', 'Renault', 'BMW',
#        'Land Rover', 'Volkswagen', 'Audi', 'Chrysler', 'Jaguar',
#        'Mitsubishi', 'Kia', 'Porsche', 'Toyota', 'Hyundai', 'Opel',
#        'Chevrolet', 'Skoda', 'Daewoo', 'Mazda', 'Lexus', 'Infiniti',
#        'Tesla', 'Subaru', 'VAZ', 'Alfa Romeo', 'Smart', 'Peugeot',
#        'Suzuki', 'Chery', 'Bentley', 'Volvo', 'SsangYong', 'Fiat', 'ZAZ',
#        'Citroen', 'Dodge', 'Jeep', 'Great Wall', 'Seat', 'MINI', 'Dacia',
#        'Hummer', 'Geely', 'Maserati', 'BYD', 'Cadillac', 'Acura',
#        'Aston Martin', 'Rover', 'GAZ', 'GMC', 'Lincoln', 'UAZ',
#        'Moskvich-AZLK', 'FAW', 'Rolls-Royce', 'TATA', 'ZX', 'Lifan',
#        'Mercury', 'Groz', 'Moskvich-Izh', 'Saab', 'Lancia', 'Aro',
#        'Ferrari', 'Isuzu', 'Bogdan', 'Dadi', 'Other-Retro', 'MG',
#        'Samand', 'JAC', 'Samsung', 'Lamborghini', 'Daihatsu', 'Hafei',
#        'SMA', 'Fisker', 'Changan', 'Barkas', 'Huanghai', 'Wartburg',
# ...

# %%
df["model"] = df["model"].apply(lambda x:x.strip("�"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 df["model"] = df["model"].apply(lambda x:x.strip("�"))
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
# ...

# %% [markdown]
# # replacing the null values.

# %%
df.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             0
# drive           510
# dtype: int64

# %%
df["engV"].dtype
# Out:
# dtype('float64')

# %%
#for repacing mean,medin mode

# %%
df["engV"].median()
# Out:
# 2.0

# %%
df["engV"].mean()
# Out:
# 2.641444235241998

# %%
df["engV"].mode()
# Out:
# 0    2.0
# Name: engV, dtype: float64

# %% [raw]
# # which to use for null values median or mean value??
# -> there are a lot of outliers so we will repace the null with median.
#
#
# #first calculate mean and median and then by using boxplot see is there any outliersin the table. if there are outliers then use median value for replacing the outliers.
#
# # Example:-
#
# category              product                price
# Electronic            Mobile                 19,000                  #Assume mean value of this price colmn is 15,000
#                       T.V                    30,000                    now replace this null value with 15,000 AC value can be 15,000
#                       AC                      -                        but we can not change the null value for jeans for 15,000.
# Clothing              T-shirt                499             So, on the bases of CAtegory we will part away the the table like, first we will calculate
#                       Shirt                  899             Electronic mean value and then for Clothing. Then replacing the null value of Electronic
#                       Jeans                   -              and then replacing null value of Clothing after calculation.
#                                                            #BY, using trandform function we can do the grouping of the table on the bases of Category.
#
#
# #same we have to do this with the main project.

# %%
sns.boxplot(x = "engV",data = df)
# Out:
# <Axes: xlabel='engV'>

# %%
df.groupby(["car","body"])["engV"].median()
#on the bases of car and boday we will calculate the the median value for engV. so now if you find the null value for crossover then we will
#replace it with 3.7
# Out:
# car         body
# Acura       crossover    3.7
#             sedan        3.2
# Alfa Romeo  hatch        1.5
#             sedan        2.2
#             vagon        1.9
#                         ...
# ZAZ         other        1.2
#             sedan        1.3
#             vagon        1.2
#             van          1.2
# ZX          crossover    2.4
# Name: engV, Length: 274, dtype: float64

# %%
df["engV"] = df.groupby(["car","body"])["engV"].transform(lambda x : x.fillna(x.median()))

# %%
df["engV"].isnull().sum()
#still if it is nt replacing the null values then we have to drop the null value column.they are of no use.
# Out:
# 9

# %%
#drive
df["drive"].dtype
# Out:
# dtype('O')

# %%
df["drive"].mode()[0]
# Out:
# 'front'

# %%
df["drive"].value_counts()
# Out:
# drive
# front    5171
# full     2422
# rear     1360
# Name: count, dtype: int64

# %%
#ho man null values are there
df["drive"].isnull().sum()
# Out:
# 510

# %%
df["drive"].fillna(value = df["drive"].mode()[0])
# Out:
# 0        full
# 1        rear
# 2        rear
# 3       front
# 4       front
#         ...
# 9571    front
# 9572    front
# 9573     full
# 9574    front
# 9575     full
# Name: drive, Length: 9463, dtype: object

# %%
df.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            9
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %%
df.dropna(inplace = True)
#used for engV because ther e are still 9 null values in the table.

# %%
df.isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            0
# engType         0
# registration    0
# year            0
# model           0
# drive           0
# dtype: int64

# %% [markdown]
# # Actual Task

# %% [markdown]
# # Which type cars are sold maximum??

# %%
df["body"].value_counts()
# Out:
# body
# sedan        3622
# crossover    2002
# hatch        1247
# van          1036
# other         828
# vagon         719
# Name: count, dtype: int64

# %%
sns.countplot(x = "body",data = df)
#so mostly sedan car sale is more.
# Out:
# <Axes: xlabel='body', ylabel='count'>

# %%
#write the insites information.

# %% [markdown]
# # what is the co-relation between price and mileage??

# %%
sns.scatterplot(x = "mileage",y = "price",data = df)
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %%
sns.regplot(x = "mileage",y="price",data = df)

#negative corelation. high price low mileage if the price is between 0 to 200000 then mileage is 

#jitna kamm mieage utna jyda price.
# Out:
# <Axes: xlabel='mileage', ylabel='price'>

# %% [markdown]
# # how many cars are registered??

# %%
sns.countplot(x = "registration",data = df)
# Out:
# <Axes: xlabel='registration', ylabel='count'>

# %%
df["registration"].value_counts()
# Out:
# registration
# yes    8893
# no      561
# Name: count, dtype: int64

# %% [markdown]
# # price distribution between registered and non-registered cars??

# %%
sns.boxplot(x = "price",y = "registration",data = df)
# Out:
# <Axes: xlabel='price', ylabel='registration'>

# %%
#registration car have high price becuase it is legal with al document but non-rgirstration there would be no document so that's why price is lower

# %% [markdown]
#  # what is the car price sistribuation based on engine value??

# %%
df
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   2.3   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
sns.scatterplot(x = "engV",y = "price",data = df)
# Out:
# <Axes: xlabel='engV', ylabel='price'>

# %%
sns.scatterplot(x = "engV",y = "price",data = df,hue ="engType")
# Out:
# <Axes: xlabel='engV', ylabel='price'>

# %% [markdown]
# # which engine type of cars users preferred maximun??

# %%
df.engType
# Out:
# 0          Gas
# 1          Gas
# 2       Petrol
# 3       Diesel
# 4        Other
#          ...
# 9571       Gas
# 9572    Petrol
# 9573    Petrol
# 9574       Gas
# 9575    Petrol
# Name: engType, Length: 9454, dtype: object

# %%
df["engType"].value_counts()
# Out:
# engType
# Petrol    4339
# Diesel    2950
# Gas       1710
# Other      455
# Name: count, dtype: int64

# %%
sns.countplot(x = "engType",data = df)
# Out:
# <Axes: xlabel='engType', ylabel='count'>

# %% [markdown]
# # establish co-relation betweenn all feature using heatmap??
#             We can not take all the column. only numerical values it will take

# %%
df[["price","mileage","engV","year"]].corr()
# Out:
#             price   mileage      engV      year
# price    1.000000 -0.312476  0.048469  0.375872
# mileage -0.312476  1.000000  0.049962 -0.490899
# engV     0.048469  0.049962  1.000000 -0.043078
# year     0.375872 -0.490899 -0.043078  1.000000

# %%
sns.heatmap(df[["price","mileage","engV","year"]].corr(),annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # Distribution of price??

# %%
sns.histplot(x = "price",data = df)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxplot(x = "price",data = df)
# Out:
# <Axes: xlabel='price'>
